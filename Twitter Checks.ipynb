# %%
import tweepy as tw
import json
import pandas as pd

from collections import defaultdict

# %%
with open("twitter_config.json") as fp:
    creds = json.load(fp)
print creds.keys()

auth = tw.OAuthHandler(creds["consumer_key"], creds["consumer_secret"])
auth.set_access_token(creds["access_token"], creds["access_token_secret"])
api = tw.API(auth)

print "Tweepy ready for search"
# Out:
# [u'consumer_secret', u'access_token', u'consumer_key', u'access_token_secret']
# Tweepy ready for search

# %%
statuses = api.search(q="Donald Trump", count=1000)

# %%
def dict2df(data):
    return pd.DataFrame(data.items(), columns=["item", "counts"]).sort_values("counts", ascending=False)

def get_entities(statuses):
    hashtags = defaultdict(int)
    mentions = defaultdict(int)
    keys = ("hashtags", "user_mentions")
    for s in statuses:
        entities = s.entities
        if "hashtags" in entities:
            e = map(lambda x: x["text"], entities["hashtags"])
            for t in e:
                hashtags[t] += 1
        if "user_mentions" in entities:
            e = map(lambda x: x["screen_name"], entities["user_mentions"])
            for t in e:
                mentions[t] += 1
    return dict2df(hashtags), dict2df(mentions)

# %%
hashtags, mentions = get_entities(statuses)

# %%
len(statuses)
# Out:
# 100

# %%
hashtags
# Out:
#                    item  counts
# 1            NeverTrump       2
# 2                 Trump       2
# 4     TakeRapeSeriously       2
# 6              CNNKFILE       2
# 9                  news       2
# 12               debate       2
# 0   HillaryHatesAmerica       1
# 3              business       1
# 5             ImWithHer       1
# 7          PowerOfWomen       1
# 8                  tech       1
# 10       TrumpVsAllOfUs       1
# 11          SamanthaBee       1
# 13               market       1
# 14            SkyPapers       1

# %%
mentions
# Out:
#                item  counts
# 8   realDonaldTrump       5
# 16           JCyrus       4
# 22          YouTube       3
# 18   kurteichenwald       3
# 59  antoniodelotero       3
# 28    BernieSanders       2
# 36          nytimes       2
# 5           NOW_NYC       2
# 6           FoxNews       2
# 32       trap_lawdd       2
# 47              CNN       2
# 51   jondoepolitics       1
# 50  elizagraceflips       1
# 49  FullFrontalSamB       1
# 48    JohnPersinos1       1
# 0       WeNeedTrump       1
# 46     kylegriffin1       1
# 52      AnandWrites       1
# 44    brunelldonald       1
# 43      GeorgeTakei       1
# 42              THR       1
# 41            sunny       1
# 45     thelindywest       1
# 55     NeYoCompound       1
# 53  tprincedelamour       1
# 54       funnyordie       1
# 39        cam294cam       1
# 56             mmfa       1
# 57     raymondbraun       1
# 58          aterkel       1
# ..              ...     ...
# 34   StefanMolyneux       1
# 38       MileyCyrus       1
# 19        baratunde       1
# 2    SusPensionPete       1
# 3           TEN_GOP       1
# 4        ananavarro       1
# 7          vicenews       1
# 9   BayoumiMoustafa       1
# 10          Variety       1
# 11  JasonMillerinDC       1
# 12    MariaTCardona       1
# 13      Mortimer_Fu       1
# 14       marceelias       1
# 15       mattaukamp       1
# 17      HuffPostPol       1
# 20           lisang       1
# 37           jbarro       1
# 21     marinhskilla       1
# 23           Acosta       1
# 24        Ayopotter       1
# 25     RBCNetworkTV       1
# 26   alyciaskristen       1
# 27          Ani973_       1
# 29       JoyAnnReid       1
# 30        iChArnold       1
# 31        Nightline       1
# 33       jaketapper       1
# 1    HillaryClinton       1
# 35              ABC       1
# 68     Complex_News       1
#
# [69 rows x 2 columns]
